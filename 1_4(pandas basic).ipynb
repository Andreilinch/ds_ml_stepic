# %%
import pandas as pd
import numpy as np

# %%
student_Performance = pd.read_csv('https://stepik.org/media/attachments/course/4852/StudentsPerformance.csv')

# %%
student_Performance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student_Performance.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
student_Performance.describe()
# Out:
#        math score  reading score  writing score
# count  1000.00000    1000.000000    1000.000000
# mean     66.08900      69.169000      68.054000
# std      15.16308      14.600192      15.195657
# min       0.00000      17.000000      10.000000
# 25%      57.00000      59.000000      57.750000
# 50%      66.00000      70.000000      69.000000
# 75%      77.00000      79.000000      79.000000
# max     100.00000     100.000000     100.000000

# %%
student_Performance.dtypes
# Out:
# gender                         object
# race/ethnicity                 object
# parental level of education    object
# lunch                          object
# test preparation course        object
# math score                      int64
# reading score                   int64
# writing score                   int64
# dtype: object

# %%
type(student_Performance.dtypes)
# Out:
# pandas.core.series.Series

# %%
student_Performance.groupby('race/ethnicity').aggregate({'math score' : 'mean'})
# R - student_Performance[,.(),.()]
# Out:
#                 math score
# race/ethnicity
# group A          61.629213
# group B          63.452632
# group C          64.463950
# group D          67.362595
# group E          73.821429

# %%
student_Performance
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
student_Performance.iloc[0:5, 0:3]
# запомнить что в питоне обязательно нужно указывать метод который мы хотим использовать, 
# то есть получается student_Performance наследует все методы pandas
# Out:
#    gender race/ethnicity parental level of education
# 0  female        group B           bachelor's degree
# 1  female        group C                some college
# 2  female        group B             master's degree
# 3    male        group A          associate's degree
# 4    male        group C                some college

# %%
student_Performance.iloc[0:5, [-1, -2, -3]]
# обратный порядок, то есть последние 3 столбца в обратном порядке и первые 5 строчек
# Out:
#    writing score  reading score  math score
# 0             74             72          72
# 1             88             90          69
# 2             93             95          90
# 3             44             57          47
# 4             75             78          76

# %%
student_Performance_with_names = student_Performance.iloc[[0, 3, 4, 7, 8]]
student_Performance_with_names
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 7    male        group B                some college  free/reduced
# 8    male        group D                 high school  free/reduced
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 3                    none          47             57             44
# 4                    none          76             78             75
# 7                    none          40             43             39
# 8               completed          64             64             67

# %%
student_Performance_with_names.index = ["Cersey", "Tywin", "Gregor", "Joffrey", "Ilyn Payne"]
student_Performance_with_names
# Out:
#             gender race/ethnicity parental level of education         lunch  \
# Cersey      female        group B           bachelor's degree      standard
# Tywin         male        group A          associate's degree  free/reduced
# Gregor        male        group C                some college      standard
# Joffrey       male        group B                some college  free/reduced
# Ilyn Payne    male        group D                 high school  free/reduced
#
#            test preparation course  math score  reading score  writing score
# Cersey                        none          72             72             74
# Tywin                         none          47             57             44
# Gregor                        none          76             78             75
# Joffrey                       none          40             43             39
# Ilyn Payne               completed          64             64             67

# %%
student_Performance_with_names.loc[['Cersey'], ['gender']]
student_Performance_with_names.loc[['Cersey'],]
# Out:
#         gender race/ethnicity parental level of education     lunch  \
# Cersey  female        group B           bachelor's degree  standard
#
#        test preparation course  math score  reading score  writing score
# Cersey                    none          72             72             74

# %%
student_Performance_with_names.iloc[:, 0]
# это не датафрейм а Серия!
# Out:
# Cersey        female
# Tywin           male
# Gregor          male
# Joffrey         male
# Ilyn Payne      male
# Name: gender, dtype: object

# %%
type(student_Performance_with_names.iloc[:, 0])
# Out:
# pandas.core.series.Series

# %%
pd.Series([1, 2, 4, 6])
# Out:
# 0    1
# 1    2
# 2    4
# 3    6
# dtype: int64

# %%
# пандасовский дата фрейм это обединенные серии !

# %%
my_series_1 = pd.Series([1, 2, 3], index = ["Cersey", "Tywin", "Gregor"])
my_series_2 = pd.Series([4, 5, 6], index = ["Tremor", "Cersey", "Gringer"])

# %%
pd.DataFrame({'col_name_1': my_series_1,'col_name_2': my_series_2})
# Out:
#          col_name_1  col_name_2
# Cersey          1.0         5.0
# Gregor          3.0         NaN
# Gringer         NaN         6.0
# Tremor          NaN         4.0
# Tywin           2.0         NaN

# %%
# просто создам df
pd.DataFrame({'col_name_1': (1, 23, 342, 4, 667, 74),'col_name_2': ('A', 'DS', 'FD', 'ER', 'C', 'V')})
# Out:
#    col_name_1 col_name_2
# 0           1          A
# 1          23         DS
# 2         342         FD
# 3           4         ER
# 4         667          C
# 5          74          V

# %%
student_Performance_with_names['gender']
# Серия
# возьми то что находится по значению gender
# Out:
# Cersey        female
# Tywin           male
# Gregor          male
# Joffrey         male
# Ilyn Payne      male
# Name: gender, dtype: object

# %%
student_Performance_with_names[['gender']]
# Data Frame
# возьми от всего дф только его первую колонку
# Out:
#             gender
# Cersey      female
# Tywin         male
# Gregor        male
# Joffrey       male
# Ilyn Payne    male

# %%
# 7 первых строк
student_Performance.iloc[:7]
student_Performance.head(7)

student_Performance.iloc[:7]

student_Performance.iloc[:7]

student_Performance.loc[:6]
student_Performance.head(7)
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
# 6  female        group B                some college      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# ...

# %%
# фильтрация по типу данных
# df.select_dtypes(include=types_to_include, exclude=types_to_exclude)

student_Performance.select_dtypes(exclude='int64')
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course
# 0                      none
# 1                 completed
# 2                      none
# ...

# %%
#student_Performance.index(1,2,3)
student_Performance.columns
# Out:
# Index(['gender', 'race/ethnicity', 'parental level of education', 'lunch',
#        'test preparation course', 'math score', 'reading score',
#        'writing score'],
#       dtype='object')

# %%
student_Performance.size
# Out:
# 8000

# %%
student_Performance.get_dtype_counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-53-385850c96025> in <module>
# ----> 1 student_Performance.get_dtype_counts()
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5272             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    5273                 return self[name]
# -> 5274             return object.__getattribute__(self, name)
#    5275
#    5276     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'get_dtype_counts'

# %%
student_Performance.shape
# Out:
# (1000, 8)

# %%
Titanic_raw = pd.read_csv('https://stepik.org/media/attachments/course/4852/titanic.csv')
Titanic_raw
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
Titanic_raw.shape
# Out:
# (891, 12)

# %%
Titanic_raw.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object
